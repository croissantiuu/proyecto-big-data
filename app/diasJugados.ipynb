# %%
import pandas as pd
from datetime import datetime
import ast

# Mapeo de los nombres de los meses a números
meses = {'Jan': '1', 'Feb': '2', 'Mar': '3', 'Apr': '4', 'May': '5', 'Jun': '6', 
         'Jul': '7', 'Aug': '8', 'Sep': '9', 'Oct': '10', 'Nov': '11', 'Dec': '12'}

# Lee el archivo CSV
df = pd.read_csv('D:/s4nti/Documents/OCTAVO SEMESTRE/PROYECTO INTEGRADOR DE TECNOLOGÍAS DE BIG DATA/PROYECTO/proyecto-big-data/data/ID Juegos Division/SantiFullWithDates.csv')

# df['Fecha de Lanzamiento']
df.head()
# Out:
#    ID del juego                                            Géneros  \
# 0        461640                      Action, Adventure, Indie, RPG
# 1           730                               Action, Free to Play
# 2        578080  Action, Adventure, Massively Multiplayer, Free...
# 3           570                     Action, Strategy, Free to Play
# 4         42690                                                NaN
#
#                                           Categorías Fecha de Lanzamiento
# 0  Single-player, Steam Achievements, Full contro...                  NaN
# 1  Multi-player, Cross-Platform Multiplayer, Stea...                  NaN
# 2  Multi-player, PvP, Online PvP, Stats, Remote P...                  NaN
# 3  Multi-player, Co-op, Steam Trading Cards, Stea...                  NaN
# 4                                                NaN                  NaN

# %%
df_limt = df.head()
df_limt.head()
# Out:
#    ID del juego                                            Géneros  \
# 0        461640                      Action, Adventure, Indie, RPG
# 1           730                               Action, Free to Play
# 2        578080  Action, Adventure, Massively Multiplayer, Free...
# 3           570                     Action, Strategy, Free to Play
# 4         42690                                                NaN
#
#                                           Categorías Fecha de Lanzamiento
# 0  Single-player, Steam Achievements, Full contro...                  NaN
# 1  Multi-player, Cross-Platform Multiplayer, Stea...                  NaN
# 2  Multi-player, PvP, Online PvP, Stats, Remote P...                  NaN
# 3  Multi-player, Co-op, Steam Trading Cards, Stea...                  NaN
# 4                                                NaN                  NaN

# %%
import numpy as np

# Función para extraer la fecha del diccionario
def extraer_fecha(diccionario):
    # Comprueba si el valor es NaN
    if pd.isna(diccionario):
        return ''
    # Convierte la cadena del diccionario en un diccionario real
    diccionario = ast.literal_eval(diccionario)
    # Comprueba si la fecha está vacía
    if diccionario['date'] == '':
        return ''
    else:
        # Devuelve la fecha
        return diccionario['date']

# Aplica la función a la columna 'Fecha de Lanzamiento'
df['Fecha'] = df['Fecha de Lanzamiento'].apply(extraer_fecha)

# Muestra el DataFrame
print(df.head())
# Out:
#    ID del juego                                            Géneros  \
# 0        461640                      Action, Adventure, Indie, RPG
# 1           730                               Action, Free to Play
# 2        578080  Action, Adventure, Massively Multiplayer, Free...
# 3           570                     Action, Strategy, Free to Play
# 4         42690                                                NaN
#
#                                           Categorías Fecha de Lanzamiento  \
# 0  Single-player, Steam Achievements, Full contro...                  NaN
# 1  Multi-player, Cross-Platform Multiplayer, Stea...                  NaN
# 2  Multi-player, PvP, Online PvP, Stats, Remote P...                  NaN
# 3  Multi-player, Co-op, Steam Trading Cards, Stea...                  NaN
# 4                                                NaN                  NaN
#
#   Fecha
# 0
# 1
# 2
# 3
# 4

# %%
df['Fecha']
# Out:
# 0
# 1
# 2
# 3
# 4
#             ...
# 4549    22 Apr, 2020
# 4550    15 Mar, 2018
# 4551    15 May, 2018
# 4552    12 Mar, 2018
# 4553    17 Mar, 2018
# Name: Fecha, Length: 4554, dtype: object

# %%
from datetime import datetime

def formatearFecha(fecha_str):
    if pd.isnull(fecha_str) or not isinstance(fecha_str, str):
        return fecha_str
    else:
        formatos = ["%d %b, %Y", "%d-%b-%Y", "%d/%m/%Y", "%Y-%m-%d"]  # Agrega aquí otros formatos que quieras probar
        for formato in formatos:
            try:
                fecha_obj = datetime.strptime(fecha_str, formato)
                return fecha_obj
            except ValueError:
                continue
        print(f"No se pudo parsear la fecha: {fecha_str}")
        return -1  # Devuelve la cadena original si no se pudo parsear

# Asegúrate de que df es tu DataFrame
df['Fecha'] = df['Fecha'].apply(formatearFecha)
# Out:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: ноя 2018
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: May 17, 2018
# No se pudo parsear la fecha: Jan 29, 2019
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 18/set./2020
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 3/ago./2020
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 6/mai./2021
# No se pudo parsear la fecha: 5 дек. 2019 r.
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 18/jun./2020
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: May 20, 2013
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 29 мая. 2015 r.
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Jun 20, 2017
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 20 oct. 2022
# No se pudo parsear la fecha: 25. März 2013
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Jun 2015
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Mar 8, 2018
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Dec 19, 2023
# No se pudo parsear la fecha: 25 июл. 2019 r.
# No se pudo parsear la fecha: 23 окт. 2023 r.
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 18 янв. 2024 r.
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 26/jan./2018
# No se pudo parsear la fecha: 16 maja 2011
# No se pudo parsear la fecha: Jan 19, 2016
# No se pudo parsear la fecha: Nov 8, 2013
# No se pudo parsear la fecha: Oct 15, 2015
# No se pudo parsear la fecha: 27. Aug. 2014
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Aug 27, 2017
# No se pudo parsear la fecha: 20. Okt. 2016
# No se pudo parsear la fecha: Jun 8, 2020
# No se pudo parsear la fecha: 13 marca 2023
# No se pudo parsear la fecha: Feb 14, 2020
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 13 дек. 2023 r.
# No se pudo parsear la fecha: 2/abr./2020
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 1/jun./2017
# No se pudo parsear la fecha: 15/fev./2016
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 22 feb 2024
# No se pudo parsear la fecha: 21/out./2022
# No se pudo parsear la fecha: Apr 2019
# No se pudo parsear la fecha: 2015 年 4 月 24 日
# No se pudo parsear la fecha: 18/mai./2015
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Mar 25, 2021
# No se pudo parsear la fecha: 30 sierpnia 2022
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Nov 2014
# No se pudo parsear la fecha: 22/mai./2018
# No se pudo parsear la fecha: Apr 19, 2023
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 20/jul./2021
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Sep 30, 2014
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 19/jul./2022
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Jun 20, 2008
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Jul 2010
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 25 stycznia 2011
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Jun 2009
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 6. Juni 2016
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Nov 11, 2014
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 4 listopada 2014
# No se pudo parsear la fecha: 4 marca 2016
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Sep 17, 2014
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 22/jul./2016
# No se pudo parsear la fecha: Jul 23, 2009
# No se pudo parsear la fecha: Aug 2013
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Aug 25, 2014
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 9/jan./2014
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Mar 23, 2023
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 9/nov./2018
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Jul 2014
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Dec 2019
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Aug 22, 2023
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Jul 8, 2021
# No se pudo parsear la fecha: Nov 17, 2023
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Jul 16, 2023
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: May 22, 2012
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Feb 5, 2014
# No se pudo parsear la fecha: Apr 3, 2014
# No se pudo parsear la fecha: Jun 5, 2014
# No se pudo parsear la fecha: Jul 10, 2014
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Mar 9, 2015
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Jul 20, 2017
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Dec 23, 2009
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Jan 29, 2015
# No se pudo parsear la fecha: Jul 21, 2015
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Jul 2010
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 19 июн. 2019 r.
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: May 15, 2014
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Apr 16, 2015
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Aug 2015
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Jan 2016
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: 18. Feb. 2014
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: May 30, 2017
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Jan 24, 2023
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Jan 2017
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Aug 31, 2022
# No se pudo parsear la fecha: Apr 14, 2022
# No se pudo parsear la fecha: Mar 24, 2023
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Jun 2009
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Nov 2020
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Aug 29, 2016
# No se pudo parsear la fecha:
# No se pudo parsear la fecha: Aug 2017

# %%
df
# Out:
#       ID del juego                                            Géneros  \
# 0           461640                      Action, Adventure, Indie, RPG
# 1              730                               Action, Free to Play
# 2           578080  Action, Adventure, Massively Multiplayer, Free...
# 3              570                     Action, Strategy, Free to Play
# 4            42690                                                NaN
# ...            ...                                                ...
# 4549        777130            Casual, Indie, Simulation, Free to Play
# 4550        784950  Free to Play, Indie, Massively Multiplayer, St...
# 4551        790600                      Free to Play, Indie, Strategy
# 4552        793350                              Action, Casual, Indie
# 4553        810670            Adventure, Casual, Indie, RPG, Strategy
#
#                                              Categorías  \
# 0     Single-player, Steam Achievements, Full contro...
# 1     Multi-player, Cross-Platform Multiplayer, Stea...
# 2     Multi-player, PvP, Online PvP, Stats, Remote P...
# 3     Multi-player, Co-op, Steam Trading Cards, Stea...
# 4                                                   NaN
# ...                                                 ...
# 4549  Single-player, Steam Achievements, In-App Purc...
# 4550  Multi-player, MMO, PvP, Online PvP, Co-op, Onl...
# 4551  Multi-player, PvP, Online PvP, Steam Achieveme...
# 4552  Single-player, Steam Achievements, Full contro...
# 4553  Single-player, Steam Achievements, Steam Tradi...
#
#                                 Fecha de Lanzamiento                Fecha
# 0                                                NaN                   -1
# 1                                                NaN                   -1
# 2                                                NaN                   -1
# 3                                                NaN                   -1
# 4                                                NaN                   -1
# ...                                              ...                  ...
# 4549  {'coming_soon': False, 'date': '22 Apr, 2020'}  2020-04-22 00:00:00
# 4550  {'coming_soon': False, 'date': '15 Mar, 2018'}  2018-03-15 00:00:00
# 4551  {'coming_soon': False, 'date': '15 May, 2018'}  2018-05-15 00:00:00
# 4552  {'coming_soon': False, 'date': '12 Mar, 2018'}  2018-03-12 00:00:00
# 4553  {'coming_soon': False, 'date': '17 Mar, 2018'}  2018-03-17 00:00:00
#
# [4554 rows x 5 columns]

# %%
import requests
def diasDesde(fecha):
    if pd.isnull(fecha) or fecha == -1.0:
        return -1  # Devuelve None si fecha no es un objeto datetime
    else:
        hoy = datetime.today().date()
        return (hoy - fecha.date()).days

# Asegúrate de que df es tu DataFrame
df['Dias_Pasados'] = df['Fecha'].apply(diasDesde)

# %%
df
# Out:
#       ID del juego                                            Géneros  \
# 0           461640                      Action, Adventure, Indie, RPG
# 1              730                               Action, Free to Play
# 2           578080  Action, Adventure, Massively Multiplayer, Free...
# 3              570                     Action, Strategy, Free to Play
# 4            42690                                                NaN
# ...            ...                                                ...
# 4549        777130            Casual, Indie, Simulation, Free to Play
# 4550        784950  Free to Play, Indie, Massively Multiplayer, St...
# 4551        790600                      Free to Play, Indie, Strategy
# 4552        793350                              Action, Casual, Indie
# 4553        810670            Adventure, Casual, Indie, RPG, Strategy
#
#                                              Categorías  \
# 0     Single-player, Steam Achievements, Full contro...
# 1     Multi-player, Cross-Platform Multiplayer, Stea...
# 2     Multi-player, PvP, Online PvP, Stats, Remote P...
# 3     Multi-player, Co-op, Steam Trading Cards, Stea...
# 4                                                   NaN
# ...                                                 ...
# 4549  Single-player, Steam Achievements, In-App Purc...
# 4550  Multi-player, MMO, PvP, Online PvP, Co-op, Onl...
# 4551  Multi-player, PvP, Online PvP, Steam Achieveme...
# 4552  Single-player, Steam Achievements, Full contro...
# 4553  Single-player, Steam Achievements, Steam Tradi...
#
#                                 Fecha de Lanzamiento                Fecha  \
# 0                                                NaN                   -1
# 1                                                NaN                   -1
# 2                                                NaN                   -1
# 3                                                NaN                   -1
# 4                                                NaN                   -1
# ...                                              ...                  ...
# 4549  {'coming_soon': False, 'date': '22 Apr, 2020'}  2020-04-22 00:00:00
# 4550  {'coming_soon': False, 'date': '15 Mar, 2018'}  2018-03-15 00:00:00
# 4551  {'coming_soon': False, 'date': '15 May, 2018'}  2018-05-15 00:00:00
# 4552  {'coming_soon': False, 'date': '12 Mar, 2018'}  2018-03-12 00:00:00
# 4553  {'coming_soon': False, 'date': '17 Mar, 2018'}  2018-03-17 00:00:00
#
#       Dias_Pasados
# 0               -1
# 1               -1
# 2               -1
# 3               -1
# 4               -1
# ...            ...
# 4549          1442
# 4550          2211
# 4551          2150
# 4552          2214
# 4553          2209
#
# [4554 rows x 6 columns]

# %%
mediaDeDias = int(df['Dias_Pasados'].mean())
print(mediaDeDias)
# Out:
# 2457

# %%
def cleanMinusOne(posibleMinusOne):
    if posibleMinusOne == -1:
        return mediaDeDias
    else:
        return posibleMinusOne
df['Dias_Pasados'] = df['Dias_Pasados'].apply(cleanMinusOne)

# %%
df
# Out:
#       ID del juego                                            Géneros  \
# 0           461640                      Action, Adventure, Indie, RPG
# 1              730                               Action, Free to Play
# 2           578080  Action, Adventure, Massively Multiplayer, Free...
# 3              570                     Action, Strategy, Free to Play
# 4            42690                                                NaN
# ...            ...                                                ...
# 4549        777130            Casual, Indie, Simulation, Free to Play
# 4550        784950  Free to Play, Indie, Massively Multiplayer, St...
# 4551        790600                      Free to Play, Indie, Strategy
# 4552        793350                              Action, Casual, Indie
# 4553        810670            Adventure, Casual, Indie, RPG, Strategy
#
#                                              Categorías  \
# 0     Single-player, Steam Achievements, Full contro...
# 1     Multi-player, Cross-Platform Multiplayer, Stea...
# 2     Multi-player, PvP, Online PvP, Stats, Remote P...
# 3     Multi-player, Co-op, Steam Trading Cards, Stea...
# 4                                                   NaN
# ...                                                 ...
# 4549  Single-player, Steam Achievements, In-App Purc...
# 4550  Multi-player, MMO, PvP, Online PvP, Co-op, Onl...
# 4551  Multi-player, PvP, Online PvP, Steam Achieveme...
# 4552  Single-player, Steam Achievements, Full contro...
# 4553  Single-player, Steam Achievements, Steam Tradi...
#
#                                 Fecha de Lanzamiento                Fecha  \
# 0                                                NaN                   -1
# 1                                                NaN                   -1
# 2                                                NaN                   -1
# 3                                                NaN                   -1
# 4                                                NaN                   -1
# ...                                              ...                  ...
# 4549  {'coming_soon': False, 'date': '22 Apr, 2020'}  2020-04-22 00:00:00
# 4550  {'coming_soon': False, 'date': '15 Mar, 2018'}  2018-03-15 00:00:00
# 4551  {'coming_soon': False, 'date': '15 May, 2018'}  2018-05-15 00:00:00
# 4552  {'coming_soon': False, 'date': '12 Mar, 2018'}  2018-03-12 00:00:00
# 4553  {'coming_soon': False, 'date': '17 Mar, 2018'}  2018-03-17 00:00:00
#
#       Dias_Pasados
# 0             2457
# 1             2457
# 2             2457
# 3             2457
# 4             2457
# ...            ...
# 4549          1442
# 4550          2211
# 4551          2150
# 4552          2214
# 4553          2209
#
# [4554 rows x 6 columns]
