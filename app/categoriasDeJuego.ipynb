# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/rodri/Documents/Python/Proyecto Integrador Big Data/data/TagsConseguidos/new_dataframe_actual_datesfull_roy.csv")
df
# Out:
#       Unnamed: 0  ID del juego  \
# 0              0        461640
# 1              1           730
# 2              2        578080
# 3              3           570
# 4              4         42690
# ...          ...           ...
# 4549        4549        777130
# 4550        4550        784950
# 4551        4551        790600
# 4552        4552        793350
# 4553        4553        810670
#
#                                                 Géneros  \
# 0                         Action, Adventure, Indie, RPG
# 1                                  Action, Free to Play
# 2     Action, Adventure, Massively Multiplayer, Free...
# 3                        Action, Strategy, Free to Play
# 4                                                   NaN
# ...                                                 ...
# 4549            Casual, Indie, Simulation, Free to Play
# 4550  Free to Play, Indie, Massively Multiplayer, St...
# 4551                      Free to Play, Indie, Strategy
# ...

# %%
categorias = df['Categorías']
categorias
# Out:
# [0       Single-player, Steam Achievements, Full contro...
#  1       Multi-player, Cross-Platform Multiplayer, Stea...
#  2       Multi-player, PvP, Online PvP, Stats, Remote P...
#  3       Multi-player, Co-op, Steam Trading Cards, Stea...
#  4                                                     NaN
#                                ...
#  4549    Single-player, Steam Achievements, In-App Purc...
#  4550    Multi-player, MMO, PvP, Online PvP, Co-op, Onl...
#  4551    Multi-player, PvP, Online PvP, Steam Achieveme...
#  4552    Single-player, Steam Achievements, Full contro...
#  4553    Single-player, Steam Achievements, Steam Tradi...
#  Name: Categorías, Length: 4554, dtype: object]
